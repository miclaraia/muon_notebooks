# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from muon.deep_clustering.clustering import Config, Cluster
from muon.utils.subjects import Subjects
import muon.config

import pickle

config = 'mnt/dec/dec_no_labels/config_jupyter.json'
config = Config.load(config)
print(config.__dict__)
subjects = pickle.load(open(config.subjects, 'rb'))
sample = subjects._sample_s(10)
# Out:
# {'lr': 0.01, 'batch_size': 256, 'ae_weights': 'mnt/dec/dec_no_labels/ae_weights.h5', 'tol': 0.001, 'momentum': 0.9, 'n_clusters': 50, 'subjects': 'mnt/dec/dec_no_labels/subjects.pkl', 'save_dir': 'mnt/dec/dec_no_labels', 'maxiter': 20000.0, 'nodes': [500, 500, 2000, 10], 'update_interval': 140}
# number of subjects 70712

# %%
muon.config.cmap = 'viridis'
sample.plot_subjects(w=10)
plt.show()

# %%
muon.config.cmap = 'magma'
sample.plot_subjects(w=10)
plt.show()

# %%
muon.config.cmap = 'plasma'
sample.plot_subjects(w=10)
plt.show()

# %%
muon.config.cmap = 'jet'
sample.plot_subjects(w=10)
plt.show()

# %%
muon.config.cmap = 'jet'
subjects.plot_sample(100, w=10)
plt.show()
# Out:
# number of subjects 70712
